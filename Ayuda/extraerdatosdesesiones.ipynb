# %%
import re
import pandas as pd

# Ruta del archivo de texto
file_path = r"C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\1.-RDL SERVIDOR DB\sesiones_rdlDB.txt"
#pattern2 = re.compile(r"(Audit\s(Success|Failure)\s+(\d{1,2}/\d{1,2}/\d{4}\s+\d{2}:\d{2}:\d{2}))", re.VERBOSE)
# Expresión regular mejorada para extraer los datos
pattern = re.compile(r"""
    Audit\s(Success|Failure)\s+(\d{1,2}/\d{1,2}/\d{4}\s+\d{2}:\d{2}:\d{2})\s*\n?                 
    \s*Subject:\s*\n?
    \s*Security\sID:\s*(.*?)\n
    \s*Account\sName:\s*(.*?)\n
    \s*Account\sDomain:\s*(.*?)\n
    \s*Logon\sID:\s*(.*?)\n
    \s*User:\s*\n?
    \s*Security\sID:\s*(.*?)\n
    \s*Account\sName:\s*(.*?)\n
    \s*Account\sDomain:\s*(.*?)\n
    \s*Process\sInformation:\s*\n?
    \s*Process\sID:\s*(.*?)\n
    \s*Process\sName:\s*(.*?)\n
""", re.VERBOSE)



# Leer el archivo y extraer los datos
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

dates = [match[2] for match in pattern.findall(text)]
matches = pattern.findall(text)

# Convertir los datos en un DataFrame
df = pd.DataFrame(matches, columns=[
    "Audit Type", "Timestamp","Subject Security ID", "Subject Account Name", "Subject Account Domain", "Logon ID",
    "User Security ID", "User Account Name", "User Account Domain",
    "Process ID", "Process Name"
])
df = pd.DataFrame(dates, columns=["Fecha"])

# Guardar en un archivo Excel
output_path = r"C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\sesiones_extraidas.xlsx"
df.to_excel(output_path, index=False)

print(f"Datos extraídos y guardados en {output_path}")
# Out:
# Datos extraídos y guardados en C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\sesiones_extraidas.xlsx

# %%
import re
import pandas as pd

# Ruta del archivo de texto
file_path = r"C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\1.-RDL SERVIDOR DB\sesiones_rdlDB.txt"

# Expresión regular para extraer la fecha y hora en formato dd/m/yyyy hh:mm:ss
pattern = re.compile(r"(Audit\s(Success|Failure)\s+(\d{1,2}/\d{1,2}/\d{4}\s+\d{2}:\d{2}:\d{2}))", re.VERBOSE)

# Leer el archivo y extraer los datos
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

# Extraer las fechas usando la expresión regular
dates = [match[2] for match in pattern.findall(text)]  # Extraemos solo la fecha y hora

# Verificar las fechas extraídas
print(f"Fechas extraídas: {dates}")

# Crear un DataFrame con las fechas
df = pd.DataFrame(dates, columns=["Fecha"])

# Guardar el DataFrame en un archivo Excel
output_path = r"C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\fechas_extraidas.xlsx"
df.to_excel(output_path, index=False)

print(f"Fechas guardadas en {output_path}")
# Out:
# Fechas extraídas: ['19/3/2025 11:37:29', '19/3/2025 11:37:28', '19/3/2025 11:36:59', '19/3/2025 11:36:57', '19/3/2025 11:36:34', '19/3/2025 11:36:33', '19/3/2025 11:36:33', '19/3/2025 11:36:32', '19/3/2025 11:36:32', '19/3/2025 11:34:31', '19/3/2025 11:34:31', '19/3/2025 11:33:33', '19/3/2025 11:33:23', '19/3/2025 11:32:18', '19/3/2025 11:32:14', '19/3/2025 11:32:14', '19/3/2025 11:31:53', '19/3/2025 11:31:53', '19/3/2025 11:31:22', '19/3/2025 11:28:56', '19/3/2025 11:28:56', '19/3/2025 11:28:49', '19/3/2025 11:28:49', '19/3/2025 11:28:37', '19/3/2025 11:28:37', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:28:00', '19/3/2025 11:27:59', '19/3/2025 11:27:59', '19/3/2025 11:27:59', '19/3/2025 11:27:59', '19/3/2025 11:27:59', '19/3/2025 11:27:59', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:56', '19/3/2025 11:27:55', '19/3/2025 11:27:55', '19/3/2025 11:27:55', '19/3/2025 11:27:55', '19/3/2025 11:27:55', '19/3/2025 11:27:55', '19/3/2025 11:27:51', '19/3/2025 11:27:51', '19/3/2025 11:27:47', '19/3/2025 11:27:47', '19/3/2025 11:27:47', '19/3/2025 11:22:23', '19/3/2025 11:19:00', '19/3/2025 11:18:47', '19/3/2025 11:18:47', '19/3/2025 11:18:46', '19/3/2025 11:16:50', '19/3/2025 11:16:50', '19/3/2025 11:16:49', '19/3/2025 11:16:49', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:16:00', '19/3/2025 11:14:49', '19/3/2025 11:14:49', '19/3/2025 11:13:24', '19/3/2025 11:10:03', '19/3/2025 11:05:35', '19/3/2025 11:05:35', '19/3/2025 11:05:35', '19/3/2025 11:05:35', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:05:19', '19/3/2025 11:04:24', '19/3/2025 11:04:24', '19/3/2025 11:04:24', '19/3/2025 11:04:24', '19/3/2025 11:04:24', '19/3/2025 11:04:24', '19/3/2025 11:04:23', '19/3/2025 11:04:23', '19/3/2025 11:04:23', '19/3/2025 11:04:23', '19/3/2025 11:04:23', '19/3/2025 11:04:23', '19/3/2025 11:04:23', '19/3/2025 11:01:03', '19/3/2025 10:57:14', '19/3/2025 10:57:14', '19/3/2025 10:57:14', '19/3/2025 10:57:14', '19/3/2025 10:56:47', '19/3/2025 10:56:47', '19/3/2025 10:56:47', '19/3/2025 10:56:40', '19/3/2025 10:56:40', '19/3/2025 10:56:40', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:49', '19/3/2025 10:55:13', '19/3/2025 10:55:13', '19/3/2025 10:54:01', '19/3/2025 10:54:01', '19/3/2025 10:54:01', '19/3/2025 10:54:01', '19/3/2025 10:54:01', '19/3/2025 10:54:01', '19/3/2025 10:54:01', '19/3/2025 10:54:00', '19/3/2025 10:54:00', '19/3/2025 10:54:00', '19/3/2025 10:54:00', '19/3/2025 10:54:00', '19/3/2025 10:54:00', '19/3/2025 10:52:43', '19/3/2025 10:52:43', '19/3/2025 10:52:43', '19/3/2025 10:52:43', '19/3/2025 10:52:36', '19/3/2025 10:52:36', ...
# Fechas guardadas en C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\fechas_extraidas.xlsx

# %%
import re
import pandas as pd

# Ruta del archivo de texto
file_path = r"C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\1.-RDL SERVIDOR DB\sesiones_rdlDB.txt"

# Expresión regular separada para extraer la fecha y el estado (Audit)
date_pattern = r"Audit\s(Success|Failure)\s+(\d{1,2}/\d{1,2}/\d{4}\s+\d{2}:\d{2}:\d{2})"

# Expresión regular para extraer la información del Subject
subject_pattern = r"""
    \s*Subject:\s*\n?
    \s*Security\sID:\s*(.*?)\n
    \s*Account\sName:\s*(.*?)\n
    \s*Account\sDomain:\s*(.*?)\n
    \s*Logon\sID:\s*(.*?)\n
"""

# Expresión regular para extraer la información del User
user_pattern = r"""
    \s*User:\s*\n?
    \s*Security\sID:\s*(.*?)\n
    \s*Account\sName:\s*(.*?)\n
    \s*Account\sDomain:\s*(.*?)\n
"""

# Expresión regular para extraer la información del Process
process_pattern = r"""
    \s*Process\sInformation:\s*\n?
    \s*Process\sID:\s*(.*?)\n
    \s*Process\sName:\s*(.*?)\n
"""

# Unir todos los patrones para extraer toda la información
full_pattern = date_pattern + r".*?" + subject_pattern + r".*?" + user_pattern + r".*?" + process_pattern

# Leer el archivo y extraer los datos
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

# Leer el archivo y extraer los datos
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

dates = [match[2] for match in pattern.findall(text)]
matches = pattern.findall(text)

# Convertir los datos en un DataFrame
df = pd.DataFrame(matches, columns=[
    "Audit Type", "Timestamp","Subject Security ID", "Subject Account Name", "Subject Account Domain", "Logon ID",
    "User Security ID", "User Account Name", "User Account Domain",
    "Process ID", "Process Name"
])
df = pd.DataFrame(dates, columns=["Fecha"])

# Guardar en un archivo Excel
output_path = r"C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\sesiones_extraidas.xlsx"
df.to_excel(output_path, index=False)

print(f"Datos extraídos y guardados en {output_path}")
# Out:
# Datos extraídos y guardados en C:\Users\eeras\OneDrive - La Fabril S.A\Escritorio\Ciberseguridad\Usuarios, logs, servicios y procesos\sesiones_extraidas.xlsx
